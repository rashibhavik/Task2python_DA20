# %%
dict1 = {
    "id": 101, "name": "Ravi", "age": 21, "marks": 88, "course": "ETC",
    "year": "Final", "city": "Nagpur", "state": "Maharashtra", "country": "India",
    "phone": "9876543210", "email": "ravi@example.com", "gender": "Male",
    "hobby": "Cricket", "language": "English", "height": 170, "weight": 65,
    "blood_group": "O+", "status": "Active", "attendance": 92, "fees_paid": True
}
print("Dict1 - Passed?", dict1["marks"] > 40)
print("From Maharashtra?", dict1["state"] == "Maharashtra")
print("Attendance >75?", dict1["attendance"] > 75)

dict2 = {
    "id": 201, "name": "Laptop", "brand": "HP", "price": 60000, "discount": 10,
    "stock": 25, "color": "Silver", "os": "Windows", "ram": "16GB", "storage": "512GB SSD",
    "graphics": "NVIDIA", "weight": "1.8kg", "warranty": "1 Year", "rating": 4.5, "seller": "HP Store",
    "category": "Electronics", "port": "USB-C", "is_available": True, "battery": "8hr", "model": "Pavilion 15"
}
final_price = dict2["price"] - (dict2["price"] * dict2["discount"] / 100)
print("Dict2 - Final Price:", final_price)
print("In Stock?", dict2["stock"] > 0)

dict3 = {
    "id": 301, "name": "Anita", "age": 29, "department": "HR", "salary": 45000,
    "bonus": 5000, "location": "Mumbai", "experience": 5, "email": "anita@xyz.com", "phone": "9876501234",
    "gender": "Female", "status": "Active", "shift": "Morning", "is_manager": False, "rating": 4.2,
    "attendance": 96, "leaves": 5, "project": "Recruitment", "team_size": 10, "work_from_home": True
}
print("Dict3 - Total Salary:", dict3["salary"]+dict3["bonus"])
print("Is Manager?", dict3["is_manager"])
print("Attendance OK?", dict3["attendance"] > 90)

dict4 = {
    "id": 401, "title": "Python Programming", "author": "Guido", "pages": 350, "price": 500,
    "publisher": "TechPress", "language": "English", "isbn": "123-456-789", "copies": 20, "category": "Education",
    "rating": 4.7, "edition": "3rd", "year": 2021, "discount": 15, "ebook": True,
    "hardcover": True, "available": True, "library_code": "PY101", "issued": 5, "remaining": 15
}
discounted_price = dict4["price"] - (dict4["price"] * dict4["discount"]/100)
print("Dict4 - Discounted Price:", discounted_price)
print("Copies Remaining:", dict4["copies"] - dict4["issued"])

dict5 = {
    "id": 501, "brand": "Toyota", "model": "Corolla", "year": 2020, "price": 15000,
    "color": "White", "mileage": 18, "engine": "1.8L", "fuel_type": "Petrol", "owner": "Company",
    "warranty": "3 Years", "insurance": True, "doors": 4, "seats": 5, "transmission": "Automatic",
    "available": True, "rating": 4.3, "service_due": "2025", "location": "Nagpur", "used": False
}
print("Dict5 - Affordable?", dict5["price"]<20000)
print("Automatic?", dict5["transmission"]=="Automatic")
print("Available?", dict5["available"])

dict6 = {
    "id": 601, "title": "Inception", "director": "Nolan", "year": 2010, "rating": 8.8,
    "language": "English", "genre": "Sci-Fi", "duration": 148, "budget": 160, "revenue": 830,
    "actors": ["Leonardo", "Joseph", "Ellen"], "oscar_nominated": True, "watched": True,
    "platform": "Netflix", "region": "Global", "age_rating": "PG-13", "sequel": False,
    "subtitle": "English", "popularity": 95, "award_won": False
}
print("Dict6 - High Rating?", dict6["rating"]>8)
print("Watched?", dict6["watched"])
print("Oscar Nominated?", dict6["oscar_nominated"])

dict7 = {
    "id": 701, "name": "MacBook", "brand": "Apple", "price": 120000, "ram": "16GB",
    "storage": "512GB SSD", "os": "MacOS", "color": "Silver", "weight": 1.4, "battery": 10,
    "warranty": "1 Year", "touchbar": True, "processor": "i7", "graphics": "Intel", "rating": 4.8,
    "seller": "Apple Store", "stock": 15, "model": "Pro 2021", "available": True, "discount": 5
}
print("Dict7 - Discounted Price:", dict7["price"]-dict7["price"]*dict7["discount"]/100)
print("Available?", dict7["available"])
print("High Rating?", dict7["rating"]>4.5)

dict8 = {
    "id": 801, "brand": "Samsung", "model": "Galaxy S21", "price": 70000, "ram": "8GB",
    "storage": "128GB", "color": "Black", "battery": 4000, "camera": 64, "os": "Android",
    "warranty": "1 Year", "dual_sim": True, "stock": 30, "rating": 4.5, "available": True,
    "seller": "Samsung Store", "discount": 10, "weight": 0.2, "year": 2021, "popularity": 90
}
print("Dict8 - Final Price:", dict8["price"]-dict8["price"]*dict8["discount"]/100)
print("Available?", dict8["available"])
print("High Rating?", dict8["rating"]>4)

dict9 = {
    "id": 901, "name": "Foodies", "city": "Nagpur", "rating": 4.5, "seating": 50,
    "open": True, "cuisine": "Indian", "takeaway": True, "delivery": True, "owner": "Ramesh",
    "employees": 10, "menu_items": 25, "avg_cost": 500, "parking": True, "wifi": True,
    "hygiene": "Good", "popular_dish": "Paneer Butter Masala", "outlet": "Main Road", "year_established": 2015, "branch": "Yes"
}
print("Dict9 - High Rating?", dict9["rating"]>4)
print("Open Now?", dict9["open"])
print("Has Delivery?", dict9["delivery"])

dict10 = {
    "id": 1001, "name": "Priya", "age": 32, "subject": "Math", "experience": 8,
    "salary": 40000, "qualification": "M.Sc", "city": "Nagpur", "gender": "Female", "department": "Science",
    "email": "priya@school.com", "phone": "9876543210", "class_assigned": "10th", "status": "Active",
    "rating": 4.6, "attendance": 95, "leaves_taken": 2, "certifications": 3, "languages_known": 2, "work_from_home": True
}
print("Dict10 - Experienced?", dict10["experience"]>5)
print("High Rating?", dict10["rating"]>4)
print("Attendance OK?", dict10["attendance"]>90)
# Out:
# Dict1 - Passed? True
# From Maharashtra? True
# Attendance >75? True
# Dict2 - Final Price: 54000.0
# In Stock? True
# Dict3 - Total Salary: 50000
# Is Manager? False
# Attendance OK? True
# Dict4 - Discounted Price: 425.0
# Copies Remaining: 15
# Dict5 - Affordable? True
# Automatic? True
# Available? True
# Dict6 - High Rating? True
# Watched? True
# Oscar Nominated? True
# Dict7 - Discounted Price: 114000.0
# Available? True
# High Rating? True
# Dict8 - Final Price: 63000.0
# Available? True
# High Rating? True
# Dict9 - High Rating? True
# Open Now? True
# Has Delivery? True
# Dict10 - Experienced? True
# High Rating? True
# Attendance OK? True
